# %% [markdown]
# # Dataset used: Iris

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import train_test_split , KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
iris = pd.read_csv('iris.data', names=["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm","Species"])
iris.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa
# 6            4.6           3.4            1.4           0.3  Iris-setosa
# 7            5.0           3.4            1.5           0.2  Iris-setosa
# 8            4.4           2.9            1.4           0.2  Iris-setosa
# 9            4.9           3.1            1.5           0.1  Iris-setosa

# %%
from sklearn.pipeline import Pipeline
x = iris.iloc[:, :-1]
y = iris.iloc[:, -1]
#sns.pairplot(x)
plt.show()
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # KNClassifier

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('KNN', KNeighborsClassifier())])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                   test_size = 0.25,
                                                   shuffle = True, #shuffle the data to avoid bias
                                                   random_state= 0)

# %%
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)
print("{:.2f}".format(f1_score(y_test, y_pred, average='macro')) )
# Out:
# 0.9736842105263158
# 0.97

# %%
def knn_test(k, x_train, y_train, x_test, y_test, weight_type, metric_type):
    pipe.set_params(KNN__n_neighbors = k, KNN__metric = metric_type, KNN__weights = weight_type)
    pipe.fit(x_train, y_train)
    y_pred = pipe.predict(x_test)
    return "{:.2f}".format(f1_score(y_test, y_pred, average='macro'))

# %%
pipe.set_params(KNN__n_neighbors = 5)
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)
print("{:.2f}".format(f1_score(y_test, y_pred, average='macro')) )
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm,
                     index = ['SETOSA','VERSICOLR','VIRGINICA'], 
                     columns = ['SETOSA','VERSICOLR','VIRGINICA'])
plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()
# Out:
# 0.97

# %%
cm
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]], dtype=int64)

# %% [markdown]
# # K-fold - Iris

# %%
def K_fold_test(k,x,y):
    cross_val = KFold(k, shuffle=True, random_state=1)
    fold_count = 1
    cm_list = []

    for train, validation in cross_val.split(x):
        print("============================================================")
        print("Fold-{}".format(fold_count))
        print("------------------------------------------------------------")

        X_train_k, y_train_k = x.iloc[train], y.iloc[train]
        X_val_k, y_val_k = x.iloc[validation], y.iloc[validation]
        pipe.fit(X_train_k, y_train_k)
        y_predict = pipe.predict(X_val_k)

        accuracy = accuracy_score(y_val_k, y_predict)
        accuracy = accuracy * 100
        f1 = f1_score(y_val_k, y_predict, average='macro')
        f1 = f1 * 100
        print("Accuracy for Fold-{} was {}%".format(fold_count, accuracy))
        print("F1-macro for Fold-{} was {:.2f}%".format(fold_count, f1))
        print("F1-macro without k-fold, previous step = {:.2f}%".format(f1_score(y_test, y_pred, average='macro')*100))
        fold_count = fold_count + 1
        print("____________________________________________________________")

# %%
print("K = 2\n")
K_fold_test(2, x,y)
print("------------")
print("K = 5\n")
K_fold_test(5, x,y)
print("------------")
print("K = 10\n")
K_fold_test(10,x,y)
# Out:
# K = 2
#
# ============================================================
# Fold-1
# ------------------------------------------------------------
# Accuracy for Fold-1 was 94.66666666666667%
# F1-macro for Fold-1 was 94.75%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-2
# ------------------------------------------------------------
# Accuracy for Fold-2 was 97.33333333333334%
# F1-macro for Fold-2 was 97.27%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ------------
# K = 5
#
# ============================================================
# Fold-1
# ------------------------------------------------------------
# Accuracy for Fold-1 was 96.66666666666667%
# F1-macro for Fold-1 was 96.10%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-2
# ------------------------------------------------------------
# Accuracy for Fold-2 was 96.66666666666667%
# F1-macro for Fold-2 was 96.80%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-3
# ------------------------------------------------------------
# Accuracy for Fold-3 was 90.0%
# F1-macro for Fold-3 was 88.99%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-4
# ------------------------------------------------------------
# Accuracy for Fold-4 was 93.33333333333333%
# F1-macro for Fold-4 was 93.27%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-5
# ------------------------------------------------------------
# Accuracy for Fold-5 was 93.33333333333333%
# F1-macro for Fold-5 was 92.67%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ------------
# K = 10
#
# ============================================================
# Fold-1
# ------------------------------------------------------------
# Accuracy for Fold-1 was 100.0%
# F1-macro for Fold-1 was 100.00%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-2
# ------------------------------------------------------------
# Accuracy for Fold-2 was 93.33333333333333%
# F1-macro for Fold-2 was 90.77%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-3
# ------------------------------------------------------------
# Accuracy for Fold-3 was 93.33333333333333%
# F1-macro for Fold-3 was 94.41%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-4
# ------------------------------------------------------------
# Accuracy for Fold-4 was 100.0%
# F1-macro for Fold-4 was 100.00%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-5
# ------------------------------------------------------------
# Accuracy for Fold-5 was 93.33333333333333%
# F1-macro for Fold-5 was 92.67%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-6
# ------------------------------------------------------------
# Accuracy for Fold-6 was 93.33333333333333%
# F1-macro for Fold-6 was 92.21%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-7
# ------------------------------------------------------------
# Accuracy for Fold-7 was 93.33333333333333%
# F1-macro for Fold-7 was 91.11%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-8
# ------------------------------------------------------------
# Accuracy for Fold-8 was 86.66666666666667%
# F1-macro for Fold-8 was 77.78%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-9
# ------------------------------------------------------------
# Accuracy for Fold-9 was 100.0%
# F1-macro for Fold-9 was 100.00%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________
# ============================================================
# Fold-10
# ------------------------------------------------------------
# Accuracy for Fold-10 was 86.66666666666667%
# F1-macro for Fold-10 was 88.89%
# F1-macro without k-fold, previous step = 97.17%
# ____________________________________________________________

# %% [markdown]
# # Testing different k-values

# %%
f1_scores = []
for i in range(1,16):
    f1_scores.append(knn_test(i,x_train,y_train,x_test,y_test,'uniform','minkowski'))
k_list = list(range(1, len(f1_scores)+1))
df = pd.DataFrame(list(zip(k_list,f1_scores)),columns = ['K', 'F1'])
df.sort_values('F1', ascending=False, inplace=True)
df
# Out:
#      K    F1
# 2    3  0.97
# 3    4  0.97
# 4    5  0.97
# 5    6  0.97
# 6    7  0.97
# 7    8  0.97
# 8    9  0.97
# 9   10  0.97
# 10  11  0.97
# 11  12  0.97
# 12  13  0.97
# 13  14  0.97
# 14  15  0.97
# 1    2  0.94
# 0    1  0.92

# %%
sns.lineplot(data=df, x ='K', y ='F1').set(title='F1 for different K in KNN Default')
plt.show()

# %%
f1_scores = []
for i in range(1,16):
    f1_scores.append(knn_test(i,x_train,y_train,x_test,y_test,'distance','euclidean'))
k_list = list(range(1, len(f1_scores)+1))
df = pd.DataFrame(list(zip(f1_scores, k_list)),columns = ['F1', 'K'])
df.sort_values('F1', ascending=False, inplace=True)
sns.lineplot(data=df, x='K', y='F1').set(title='F1 for different K in KNN distance - euclidean')
plt.show()

# %%
f1_scores = []
for i in range(1,16):
    f1_scores.append(knn_test(i,x_train,y_train,x_test,y_test,'distance','chebyshev'))
k_list = list(range(1, len(f1_scores)+1))
df = pd.DataFrame(list(zip(f1_scores, k_list)),columns = ['F1', 'K'])
df.sort_values('F1', ascending=False, inplace=True)
sns.lineplot(data=df, x='K', y='F1').set(title='F1 for different K in KNN distance - chebyshev')
plt.show()

# %% [markdown]
# # Wine Dataset

# %%
wine = pd.read_csv('wine.data', names=["Class","Alcohol","Malic acid","Ash","Alcalinity of ash",
                                       "Magnesium","Total phenols","Flavanoids","Nonflavanoid phenols",
                                        "Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted wines",
                                       "Proline"])
wine.head(10)
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
# 5      1    14.20        1.76  2.45               15.2        112
# 6      1    14.39        1.87  2.45               14.6         96
# 7      1    14.06        2.15  2.61               17.6        121
# 8      1    14.83        1.64  2.17               14.0         97
# 9      1    13.86        1.35  2.27               16.0         98
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
# 5           3.27        3.39                  0.34             1.97
# 6           2.50        2.52                  0.30             1.98
# 7           2.60        2.51                  0.31             1.25
# 8           2.80        2.98                  0.29             1.98
# 9           2.98        3.15                  0.22             1.85
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# 1             4.38  1.05                          3.40     1050
# 2             5.68  1.03                          3.17     1185
# 3             7.80  0.86                          3.45     1480
# 4             4.32  1.04                          2.93      735
# 5             6.75  1.05                          2.85     1450
# 6             5.25  1.02                          3.58     1290
# 7             5.05  1.06                          3.58     1295
# 8             5.20  1.08                          2.85     1045
# 9             7.22  1.01                          3.55     1045

# %%
x = wine.iloc[:, 1:]
y = wine.iloc[:, 0]
plt.show()

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y,
                                                   test_size = 0.25,
                                                   shuffle = True, #shuffle the data to avoid bias
                                                   random_state= 0)

# %%
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)
print("{:.2f}".format(f1_score(y_test, y_pred, average='macro')) )
# Out:
# 0.93

# %%
pipe.set_params(KNN__n_neighbors = 5)
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)
print("{:.2f}".format(f1_score(y_test, y_pred, average='macro')) )
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm)
plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()
cm
# Out:
# 0.95
# array([[16,  0,  0],
#        [ 1, 19,  1],
#        [ 0,  0,  8]], dtype=int64)

# %% [markdown]
# Testy K-foldów dla WINE

# %%
print("K = 2\n")
K_fold_test(2, x,y)
print("------------")
print("K = 5\n")
K_fold_test(5, x,y)
print("------------")
print("K = 10\n")
K_fold_test(10,x,y)
# Out:
# K = 2
#
# ============================================================
# Fold-1
# ------------------------------------------------------------
# Accuracy for Fold-1 was 91.01123595505618%
# F1-macro for Fold-1 was 91.22%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-2
# ------------------------------------------------------------
# Accuracy for Fold-2 was 91.01123595505618%
# F1-macro for Fold-2 was 91.23%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ------------
# K = 5
#
# ============================================================
# Fold-1
# ------------------------------------------------------------
# Accuracy for Fold-1 was 94.44444444444444%
# F1-macro for Fold-1 was 94.33%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-2
# ------------------------------------------------------------
# Accuracy for Fold-2 was 94.44444444444444%
# F1-macro for Fold-2 was 95.21%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-3
# ------------------------------------------------------------
# Accuracy for Fold-3 was 86.11111111111111%
# F1-macro for Fold-3 was 86.60%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-4
# ------------------------------------------------------------
# Accuracy for Fold-4 was 97.14285714285714%
# F1-macro for Fold-4 was 97.43%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-5
# ------------------------------------------------------------
# Accuracy for Fold-5 was 85.71428571428571%
# F1-macro for Fold-5 was 86.00%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ------------
# K = 10
#
# ============================================================
# Fold-1
# ------------------------------------------------------------
# Accuracy for Fold-1 was 94.44444444444444%
# F1-macro for Fold-1 was 95.21%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-2
# ------------------------------------------------------------
# Accuracy for Fold-2 was 94.44444444444444%
# F1-macro for Fold-2 was 93.73%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-3
# ------------------------------------------------------------
# Accuracy for Fold-3 was 94.44444444444444%
# F1-macro for Fold-3 was 95.22%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-4
# ------------------------------------------------------------
# Accuracy for Fold-4 was 94.44444444444444%
# F1-macro for Fold-4 was 94.75%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-5
# ------------------------------------------------------------
# Accuracy for Fold-5 was 88.88888888888889%
# F1-macro for Fold-5 was 89.68%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-6
# ------------------------------------------------------------
# Accuracy for Fold-6 was 94.44444444444444%
# F1-macro for Fold-6 was 94.34%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-7
# ------------------------------------------------------------
# Accuracy for Fold-7 was 100.0%
# F1-macro for Fold-7 was 100.00%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-8
# ------------------------------------------------------------
# Accuracy for Fold-8 was 94.44444444444444%
# F1-macro for Fold-8 was 95.01%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-9
# ------------------------------------------------------------
# Accuracy for Fold-9 was 82.35294117647058%
# F1-macro for Fold-9 was 81.82%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________
# ============================================================
# Fold-10
# ------------------------------------------------------------
# Accuracy for Fold-10 was 88.23529411764706%
# F1-macro for Fold-10 was 86.61%
# F1-macro without k-fold, previous step = 95.36%
# ____________________________________________________________

# %%
f1_scores = []
for i in range(1,16):
    f1_scores.append(knn_test(i,x_train,y_train,x_test,y_test,'uniform','minkowski'))
k_list = list(range(1, len(f1_scores)+1))
df = pd.DataFrame(list(zip(k_list,f1_scores)),columns = ['K', 'F1'])
df.sort_values('F1', ascending=False, inplace=True)
sns.lineplot(data=df, x ='K', y ='F1').set(title='F1 for different K in KNN - Uniform Minkowski')
plt.show()

# %%
f1_scores = []
for i in range(1,16):
    f1_scores.append(knn_test(i,x_train,y_train,x_test,y_test,'distance','minkowski'))
k_list = list(range(1, len(f1_scores)+1))
df = pd.DataFrame(list(zip(k_list,f1_scores)),columns = ['K', 'F1'])
df.sort_values('F1', ascending=False, inplace=True)
sns.lineplot(data=df, x ='K', y ='F1').set(title='F1 for different K in KNN - Uniform Minkowski')
plt.show()

# %%
def custom_weights(distances):
    return 1 / (distances ** 2)
f1_scores = []
for i in range(1,16):
    f1_scores.append(knn_test(i,x_train,y_train,x_test,y_test,custom_weights,'minkowski'))
k_list = list(range(1, len(f1_scores)+1))
df = pd.DataFrame(list(zip(k_list,f1_scores)),columns = ['K', 'F1'])
df.sort_values('F1', ascending=False, inplace=True)
sns.lineplot(data=df, x ='K', y ='F1').set(title='F1 for different K in KNN - Custom Minkowski')
plt.show()

# %%
f1_scores = []
for i in range(1,16):
    f1_scores.append(knn_test(i,x_train,y_train,x_test,y_test,'distance','chebyshev'))
k_list = list(range(1, len(f1_scores)+1))
df = pd.DataFrame(list(zip(k_list,f1_scores)),columns = ['K', 'F1'])
df.sort_values('F1', ascending=False, inplace=True)
sns.lineplot(data=df, x ='K', y ='F1').set(title='F1 for different K in KNN - Distance Chebyshev')
plt.show()

# %% [markdown]
# # Polish companies bankruptcy

# %%
from scipy.io import arff
from sklearn.preprocessing import MultiLabelBinarizer

data = arff.loadarff('2year.arff')
bank_df = pd.DataFrame(data[0])
#df['Attr6'].value_counts(dropna=False)
bank_df
bank_df.isna().sum()
bank_df = bank_df.drop(columns=['Attr37', 'Attr21'])
bank_df = bank_df.fillna(bank_df.median())
# simple imputer

# %%
percent_missing = bank_df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': bank_df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
print(missing_value_df)

bank_df.head(20)
# Out:
#        column_name  percent_missing
# Attr1        Attr1              0.0
# Attr50      Attr50              0.0
# Attr36      Attr36              0.0
# Attr38      Attr38              0.0
# Attr39      Attr39              0.0
# ...            ...              ...
# Attr28      Attr28              0.0
# Attr29      Attr29              0.0
# Attr30      Attr30              0.0
# Attr31      Attr31              0.0
# class        class              0.0
#
# [63 rows x 2 columns]
#        Attr1    Attr2     Attr3      Attr4    Attr5     Attr6     Attr7  \
# 0   0.202350  0.46500  0.240380    1.51710  -14.547  0.510690  0.253660
# 1   0.030073  0.59563  0.186680    1.33820  -37.859 -0.000319  0.041670
# 2   0.257860  0.29949  0.665190    3.22110   71.799  0.000000  0.318770
# 3   0.227160  0.67850  0.042784    1.08280  -88.212  0.000000  0.285050
# 4   0.085443  0.38039  0.359230    1.94440   21.731  0.187900  0.108230
# 5   0.287840  0.55225  0.316340    1.70330   38.803  0.390120  0.287840
# 6   0.153820  0.47248  0.311790    1.68980  -71.985  0.000000  0.190810
# 7   0.262520  0.45834  0.417040    1.94060   47.511  0.000000  0.262520
# 8   0.079147  0.02240  0.897050  283.12000  139.750  0.000000  0.097916
# 9   0.009901  0.71174  0.065186    1.14850  -62.297  0.000000  0.013459
# 10  0.145320  0.76682  0.208700    1.27220  -90.839  0.000000  0.185480
# 11  0.078337  0.52424  0.165900    1.32150  -25.687 -0.494160  0.078337
# 12 -0.044460  0.11409  0.151960    2.33190  -48.066 -0.127010 -0.040333
# 13  0.179490  0.42473  0.552350    2.45160   42.408  0.553430  0.223930
# 14  0.124600  0.20223  0.169850    3.15630   92.043  0.426760  0.147910
# 15 -0.041742  0.25776  0.257140    3.02850   32.628 -0.054287 -0.036406
# 16 -0.505250  1.63850 -0.787810    0.50685 -138.710 -0.624420 -0.503850
# 17  0.293070  0.28497  0.499700    2.75350  112.970  0.717330  0.364680
# 18  0.113590  0.20048  0.486870    3.63990   69.985  0.171790  0.141070
# 19  0.116600  0.44238  0.215830    1.48790   16.583  0.000000  0.155980
#
#        Attr8    Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# 0    0.91816  1.15190  0.42695  ...  0.131840  0.473950  0.86816  0.000240
# 1    0.67890  0.32356  0.40437  ...  0.121460  0.074369  0.87235  0.000000
# 2    2.33200  1.67620  0.69841  ...  0.164990  0.369210  0.81614  0.000000
# 3    0.47384  1.32410  0.32150  ...  0.293580  0.706570  0.78617  0.484560
# 4    1.37140  1.11260  0.52167  ...  0.101240  0.163790  0.89876  0.000000
# 5    0.80761  1.29200  0.44600  ...  0.225990  0.645370  0.77401  0.229690
# 6    1.11650  1.50460  0.52752  ...  0.142170  0.291600  0.87368  0.030421
# 7    1.18180  2.18540  0.54166  ...  0.625180  0.484660  0.38590  0.000000
# 8   43.64300  0.61657  0.97760  ...  0.168460  0.080961  0.86061  0.014807
# 9    0.40500  1.17380  0.28826  ...  0.203090  0.034347  0.83056  0.720470
# 10   0.30409  2.04450  0.23318  ...  0.130540  0.623210  0.90936  0.000000
# 11   0.90753  3.24570  0.47576  ...  0.293490  0.164660  0.70790  0.000000
# 12   6.90290  0.94472  0.78755  ... -0.058513 -0.056453  1.05850  0.000000
# 13   1.35440  1.10230  0.57527  ...  0.092802  0.312010  0.90720  0.076880
# 14   3.94480  1.27470  0.79777  ...  0.215480  0.156190  0.78452  0.154760
# 15   2.87960  0.96582  0.74224  ... -0.035392 -0.056238  1.03540  0.176480
# 16  -0.42649  0.93176 -0.69879  ... -0.073233  0.723030  1.07320 -0.058625
# 17   2.39190  1.27620  0.68161  ...  0.216430  0.429970  0.78357  0.000000
# 18   3.90440  1.05530  0.78276  ...  0.052379  0.145110  0.94762  0.020508
# 19   1.26050  1.92230  0.55762  ...  0.087985  0.209100  0.91927  0.000000
#
#      Attr60    Attr61    Attr62     Attr63    Attr64  class
# 0    8.5487   5.16550  107.7400    3.38790   5.34400   b'0'
# 1    1.5264   0.63305  622.6600    0.58619   1.23810   b'0'
# 2    4.3325   3.19850   65.2150    5.59690  47.46600   b'0'
# 3    5.2309   5.06750  142.4600    2.56210   3.00660   b'0'
# 4    5.7035   4.00200   89.0580    4.09840   5.98740   b'0'
# 5    7.8151   3.15340  110.8300    3.29330   6.33460   b'0'
# 6    2.6734   7.80930  109.6400    3.32910   6.36920   b'0'
# 7    7.7696   4.57600   74.0550    4.92880  15.65800   b'0'
# 8   14.2180  79.20300    1.8823  193.91000   6.17980   b'0'
# 9    7.7605   4.12530  136.5400    2.67320   2.36800   b'0'
# 10   3.1457   6.64480  136.9000    2.66620  83.52800   b'0'
# 11  12.6000   9.12930   58.0220    6.29070  10.20200   b'0'
# 12   3.1880  19.10600   69.1190    5.28080   0.82087   b'0'
# 13   9.3788   4.90680   53.7340    6.79270  38.49200   b'0'
# 14   9.7697   3.14200   51.8240    7.04310   0.73834   b'0'
# 15   3.7720   7.19740   64.2080    5.68470   1.16960   b'0'
# 16  12.7800   6.85690  247.0800    1.47730  12.40200   b'0'
# 17  24.7670   3.90040   59.6720    6.11680   8.09500   b'0'
# 18  10.7470  11.00000   37.7320    9.67350   5.42760   b'0'
# 19  22.4620   3.78250   83.9980    4.34540   5.62420   b'0'
#
# [20 rows x 63 columns]

# %%
x = bank_df.iloc[:, :-1]
y = bank_df.iloc[:, -1]
print(y)
print(type(y))
y = MultiLabelBinarizer().fit_transform(y)
y = y[: , 1]
y = pd.Series(y) 
y
print(type(y))
# Out:
# 0        b'0'
# 1        b'0'
# 2        b'0'
# 3        b'0'
# 4        b'0'
#          ...
# 10168    b'1'
# 10169    b'1'
# 10170    b'1'
# 10171    b'1'
# 10172    b'1'
# Name: class, Length: 10173, dtype: object
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                   test_size = 0.25,
                                                   shuffle = True, #shuffle the data to avoid bias
                                                   random_state= 0)

# %%
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)
print("{:.2f}".format(f1_score(y_test, y_pred, average='macro')) )
# Out:
# 0.49

# %%
pipe.set_params(KNN__n_neighbors = 5)
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)
print("{:.2f}".format(f1_score(y_test, y_pred, average='macro')) )
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm)
plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()
cm
# precision per klassa dla 1
# Out:
# 0.49
# array([[2443,    3],
#        [  98,    0]], dtype=int64)

# %%
print("K = 2\n")
K_fold_test(2, x,y)
print("------------")
print("K = 5\n")
K_fold_test(5, x,y)
print("------------")
print("K = 10\n")
K_fold_test(10,x,y)
# Out:
# K = 2
#
# ============================================================
# Fold-1
# ------------------------------------------------------------
# Accuracy for Fold-1 was 96.18635738156084%
# F1-macro for Fold-1 was 49.03%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-2
# ------------------------------------------------------------
# Accuracy for Fold-2 was 95.81203303185214%
# F1-macro for Fold-2 was 49.40%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ------------
# K = 5
#
# ============================================================
# Fold-1
# ------------------------------------------------------------
# Accuracy for Fold-1 was 96.06879606879608%
# F1-macro for Fold-1 was 49.00%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-2
# ------------------------------------------------------------
# Accuracy for Fold-2 was 95.87223587223586%
# F1-macro for Fold-2 was 48.95%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-3
# ------------------------------------------------------------
# Accuracy for Fold-3 was 96.21621621621622%
# F1-macro for Fold-3 was 49.04%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-4
# ------------------------------------------------------------
# Accuracy for Fold-4 was 95.6243854473943%
# F1-macro for Fold-4 was 48.88%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-5
# ------------------------------------------------------------
# Accuracy for Fold-5 was 95.91937069813176%
# F1-macro for Fold-5 was 48.96%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ------------
# K = 10
#
# ============================================================
# Fold-1
# ------------------------------------------------------------
# Accuracy for Fold-1 was 95.28487229862476%
# F1-macro for Fold-1 was 48.79%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-2
# ------------------------------------------------------------
# Accuracy for Fold-2 was 96.85658153241651%
# F1-macro for Fold-2 was 49.20%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-3
# ------------------------------------------------------------
# Accuracy for Fold-3 was 95.97249508840865%
# F1-macro for Fold-3 was 48.97%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-4
# ------------------------------------------------------------
# Accuracy for Fold-4 was 95.67354965585054%
# F1-macro for Fold-4 was 48.89%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-5
# ------------------------------------------------------------
# Accuracy for Fold-5 was 96.8534906588004%
# F1-macro for Fold-5 was 49.20%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-6
# ------------------------------------------------------------
# Accuracy for Fold-6 was 95.77187807276303%
# F1-macro for Fold-6 was 48.92%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-7
# ------------------------------------------------------------
# Accuracy for Fold-7 was 95.08357915437561%
# F1-macro for Fold-7 was 48.74%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-8
# ------------------------------------------------------------
# Accuracy for Fold-8 was 95.87020648967551%
# F1-macro for Fold-8 was 48.95%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-9
# ------------------------------------------------------------
# Accuracy for Fold-9 was 96.46017699115043%
# F1-macro for Fold-9 was 49.10%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________
# ============================================================
# Fold-10
# ------------------------------------------------------------
# Accuracy for Fold-10 was 95.37856440511308%
# F1-macro for Fold-10 was 48.82%
# F1-macro without k-fold, previous step = 48.99%
# ____________________________________________________________

# %%
f1_scores = []
for i in range(1,16):
    f1_scores.append(knn_test(i,x_train,y_train,x_test,y_test,'uniform','minkowski'))
k_list = list(range(1, len(f1_scores)+1))
df = pd.DataFrame(list(zip(k_list,f1_scores)),columns = ['K', 'F1'])
df.sort_values('F1', ascending=False, inplace=True)
sns.lineplot(data=df, x ='K', y ='F1').set(title='F1 for different K in KNN Default')
plt.show()

# %%
f1_scores = []
for i in range(1,16):
    f1_scores.append(knn_test(i,x_train,y_train,x_test,y_test,'distance','euclidean'))
k_list = list(range(1, len(f1_scores)+1))
df = pd.DataFrame(list(zip(f1_scores, k_list)),columns = ['F1', 'K'])
df.sort_values('F1', ascending=False, inplace=True)
sns.lineplot(data=df, x='K', y='F1').set(title='F1 for different K in KNN distance - euclidean')
plt.show()

# %%
f1_scores = []
for i in range(1,16):
    f1_scores.append(knn_test(i,x_train,y_train,x_test,y_test,'distance','chebyshev'))
k_list = list(range(1, len(f1_scores)+1))
df = pd.DataFrame(list(zip(f1_scores, k_list)),columns = ['F1', 'K'])
df.sort_values('F1', ascending=False, inplace=True)
sns.lineplot(data=df, x='K', y='F1').set(title='F1 for different K in KNN distance - chebyshev')
plt.show()
